# %% [markdown]
# ##### Spam Mail Classification
# The project is relating to classifying the messages as spam or not. We will use the nltk and Machine Learning libraries for the same.

# %%
# importing pandas to read the csv file
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
df=pd.read_csv("messages.csv")

# %%
df
# Out:
#                                                 subject  \
# 0               job posting - apple-iss research center
# 1                                                   NaN
# 2     query : letter frequencies for text identifica...
# 3                                                  risk
# 4                              request book information
# ...                                                 ...
# 2888                       love your profile - ysuolvpv
# 2889                 you have been asked to join kiddin
# 2890                 anglicization of composers ' names
# 2891  re : 6 . 797 , comparative method : n - ary co...
# 2892               re : american - english in australia
#
#                                                 message  label
# 0     content - length : 3386 apple-iss research cen...      0
# 1     lang classification grimes , joseph e . and ba...      0
# 2     i am posting this inquiry for sergei atamas ( ...      0
# 3     a colleague and i are researching the differin...      0
# 4     earlier this morning i was on the phone with a...      0
# ...                                                 ...    ...
# 2888  hello thanks for stopping by ! ! we have taken...      1
# 2889  the list owner of : " kiddin " has invited you...      1
# 2890  judging from the return post , i must have sou...      0
# 2891  gotcha ! there are two separate fallacies in t...      0
# 2892  hello ! i ' m working on a thesis concerning a...      0
#
# [2893 rows x 3 columns]

# %%
# checking the shape of the dataframe
df.shape
# Out:
# (2893, 3)

# %%
# checking the datatypes of the dataframe
df.dtypes
# Out:
# subject    object
# message    object
# label       int64
# dtype: object

# %%
#checking the null values in the dataset
df.isnull().sum()
#62 values in the subject column
# Out:
# subject    62
# message     0
# label       0
# dtype: int64

# %%
#Filling the null values with the term 'Not Available'
df['subject']=df['subject'].fillna('Not Available')

# %%
# importing nltk and other necessary libraries
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from string import punctuation
import string

# %%
# importing stemming libraries and initialising them
from nltk.stem import WordNetLemmatizer, PorterStemmer
wordnet=WordNetLemmatizer()
import re
stemmer=PorterStemmer()

# %%
# creating a separate list for storing the processed data of the column 'Subject'
subject=[]
for i in range(0, len(df['subject'])):
    review=re.sub('[^a-zA-Z]',' ', df['subject'][i])
    review=review.lower()
    review=review.split()
    review=[stemmer.stem(word) for word in review if not word in string.punctuation if not word in stopwords.words('english')]
    review= ' '.join(review)
    subject.append(review)
               
                      
subject
# Out:
# ['job post appl iss research center',
#  'avail',
#  'queri letter frequenc text identif',
#  'risk',
#  'request book inform',
#  'call abstract optim syntact theori',
#  'scandinavian linguist',
#  'call paper linguist session mla',
#  'foreign languag commerci',
#  'fulbright announc pleas post dissemin list',
#  'gala call paper',
#  'bu conf languag develop announc',
#  'korean softwar macintosh',
#  'avail',
#  'simultan preposit postposit pashto',
#  'sum imper without subject',
#  'polici',
#  'correct hellenist greek announc',
#  'question audio sampl',
#  'sexism languag',
#  'teach english korea',
#  'free',
#  'email address w dressler',
#  'dhumbadji journal histori languag',
#  'question quantit inform',
#  'amhar',
#  'uniformitarian',
#  'qs phonem write',
#  'intens summer arab languag institut',
#  'list compar literatur',
#  'call abstract',
#  'call paper rocl',
#  'stress bibliographi',
#  'depend grammar',
#  'call paper system workshop',
#  'sum e mail citat',
#  'job announc',
#  'address chang changement adress',
#  'internet success toolbox',
#  'job announc academia sinica',
#  'penn work paper',
#  'icslp',
#  'yiddish orthographi',
#  'recommend ling font set mac',
#  'gurt confer program',
#  'q german linguist term',
#  'esl curriculum',
#  'esslli',
#  'disc sex lang',
#  'english bilingu',
#  'workshop focu st call paper',
#  'question norwegian',
#  'idiom',
#  'cfp workshop spoken languag gener multimod',
#  'q influenc tone write',
#  'cite e text',
#  'salford seminar',
#  'queri latin romanc',
#  'voyeur de ton',
#  'phrase identif',
#  'ipa',
#  'slow spanish accent',
#  'conf translat literatur film',
#  'palindrom',
#  'hold manag hand',
#  'correct call abstract',
#  'www server',
#  'info request',
#  'word opposit part',
#  'avail',
#  'french english neolog',
#  'wrong lctl gopher path',
#  'qs syllabu english linguist',
#  'wccfl predic workshop preliminari program',
#  'summer opportun',
#  'refer slavic syntax',
#  'grammat relat deriv notion',
#  'sapir whorf',
#  'qs',
#  'japanes specialist need',
#  'side galicismo',
#  'refer non human languag',
#  'sum v initi languag',
#  'escol',
#  'free stealth bulk email softwar',
#  'need money',
#  'cabl decsrambl',
#  'intern sign linguist associ',
#  'ceth summer seminar electron text human',
#  'summari borrow replac ear',
#  'summari german term sibil shibil etc',
#  'eskimo snow scottish rain',
#  'request free sampl inform',
#  'best softwar best',
#  'hey interest free xxx site',
#  'job announc spanish sociolinguist ohio state univ',
#  'seek langack refer',
#  '',
#  'develop discours analysi gl',
#  'summari multimod ref',
#  'sum progress futur time refer',
#  'grammar syntax cours colleg freshman sophomor level',
#  'awali',
#  'new market technolog beyond email',
#  'n want find',
#  'special brazilian indigen languag',
#  'sum ipa histori hacek',
#  'avail',
#  'open letter languag',
#  'wkshp earli e ural interact',
#  'chechen',
#  'web site internet gold mine',
#  'webentrepreneur million sweepstak',
#  'case system use',
#  'english isol lang',
#  'palat glide',
#  'dear websit oper',
#  'uniqu email advertis',
#  'nlp',
#  'aisb sheffield registr con work tut',
#  'look horn negat book',
#  'sycopahnt sign fig',
#  'n ari vs binari',
#  'languag speci',
#  'sle confer announc',
#  'sum beaver revisit',
#  'q french aspect',
#  'literari text cd',
#  'semiot view win do musement',
#  'second cfp tsm',
#  'help spanish translat',
#  'colloc french rapid fwd',
#  'sumiko ad',
#  'date materi',
#  'qs languag attitud studi german',
#  'tree macro latex',
#  'currenc name summari',
#  'psoriasi clear',
#  'hi',
#  'em best softwar best',
#  'help teach stress intro phonet',
#  'phonem write',
#  'disc',
#  'ie confer',
#  'summari translat philosoph text textual critic',
#  'summari adposit use eye',
#  'maya mayan languag',
#  'gmt',
#  'first isra seminar comput linguist',
#  'disc sex lang',
#  'studi sla hungarian',
#  'learn style strategi research',
#  'japanes discours analysi',
#  'help make world better place',
#  'conform',
#  'viagra',
#  'kroch constant rate hypothesi',
#  'one afford dental offer',
#  'em simpli best best',
#  'time financi freedom',
#  'dave check one',
#  'endang languag',
#  'antipass reflex',
#  'corpuy ling journal',
#  'sum regist pre school age',
#  'call contribut',
#  'sum walloon',
#  'disc sex lang',
#  'pleas read',
#  'hi',
#  'great busi opportun',
#  'get right email address',
#  'efl posit israel',
#  'compar method polar review',
#  'greenberg sigh',
#  'disc uniformitarian sex lang',
#  'updat webpag slrf',
#  'bulgarian summer class u',
#  'complet internet busi sourc',
#  'need know background want know background need know background',
#  'clean e mail address',
#  'ipa',
#  'endang languag info want',
#  'conf',
#  'sum object affix',
#  'intern sign linguist associ',
#  'ipa',
#  'web promot spider',
#  'n ari comparison',
#  'hey',
#  'ultim free xxx experi',
#  'elsnet',
#  'call lowland l discuss list',
#  'sapir whorf tell student day',
#  'obituari zhou zu mo',
#  'sum versu inc',
#  'sex bia epicen',
#  'genet classif',
#  'go',
#  'profit technolog',
#  'summari vowel sound symbol',
#  'job opportun celex netherland',
#  'baal book prize',
#  'conf alasa second final call paper',
#  'disc sex lang',
#  'job offer',
#  'innat',
#  'ipa austerlitz',
#  'free market money secret',
#  'afford famili dental care',
#  'summari pars ambigu sequenc v languag',
#  'sum greek l',
#  'need know background',
#  'unlimit cash million mail',
#  'invit',
#  'lg speci',
#  'hacek',
#  'qs cree new guinea languag karcevskij dick armey',
#  'job post',
#  'posit avail dragon system speech recognit',
#  'disc sex languag',
#  'efl posit',
#  'sum c gemin',
#  'sum german english translat softwar',
#  'sum word opposit part',
#  'ipa',
#  'job english keio univ nd post',
#  'languag speci',
#  'regard cabl tv descrambl',
#  '',
#  'summari name day',
#  'link correct million sweepstak',
#  'job announc taiwan univers',
#  'ipa',
#  'qs literari text cd j rosco maya mayan lg',
#  'announc j e flege',
#  'word opposit',
#  'job appli linguist',
#  'innat',
#  'summari q articl',
#  'linguist impact internet',
#  'ipa',
#  'disc kinship term',
#  'confer announc call paper',
#  'comput linguist j',
#  'cfp paclic nd call',
#  'confer announc call paper celtic linguist',
#  'braill ipa',
#  'english parser tagger',
#  'sum c gemin syntact',
#  'disc kinship term',
#  'optim artifici languag humour',
#  'cite e text summari',
#  'word opposit sum cont',
#  'word opposit',
#  'chines roman gwoyeu romatzyh',
#  'japanes sec lang acq workshop',
#  'preliminari announc jakobson confer bulgarian',
#  'avail',
#  'kinship term',
#  'phonem bigram',
#  'chess endgam fwd',
#  'tilburg confer ot',
#  'disc uniformitarian',
#  'sum word opposit part',
#  'scandinavian linguist',
#  'disc sex lang',
#  'sum written sign speech',
#  'sycoph fig show er',
#  'summari english isol lg',
#  'fifth intern confer chines linguist',
#  'call paper',
#  'disc kinship term',
#  'call paper jengl',
#  'disc sex lang',
#  'msu syntax posit',
#  'word opposit',
#  'sum sycoph sign fig',
#  'hi',
#  'ldc unit nation corpu',
#  'sum urdu materi us',
#  'unlimit cash million mail',
#  'sycoph',
#  'sum risk',
#  'fellowship applic lsa linguist institut',
#  'hattori die',
#  'call field report endang lg lsa',
#  'word opposit',
#  'summari sociolinguist cours syllabi',
#  'bisfai deadlin extens',
#  'th intern confer function grammar',
#  'releas agfl home page',
#  'ial east asian perspect',
#  'job open ucla',
#  'phonet text',
#  'linguist scienc fiction',
#  'j r firth context situat',
#  'gl develop discours analysi',
#  'www page south african confer',
#  'asl dictionari cd rom',
#  'machin translat summit vi',
#  'yuen ren chao',
#  'chang journal languag',
#  'aaa',
#  'interim summari anthropoid linguist abil',
#  'malc final call paper',
#  'job c lisp kr nl austin tx',
#  'icl program',
#  'depend grammar correct reaction reformat',
#  'avail',
#  'fraca project comput semant deliver www home page',
#  'ipa vs americanist symbol',
#  'child languag',
#  'www address linguist unc',
#  'avail',
#  'sum histori capitalis english',
#  'line librari catalog',
#  'latvian languag polici',
#  'toc linguist list',
#  'histori linguist grammat praxi',
#  'avail',
#  'job india',
#  'new multidisciplinari period call comment',
#  'mt summit v',
#  'sum histori capitalis english',
#  'high german southern germani',
#  'temp posit syntax',
#  'ipa',
#  'sentenc process confer schedul',
#  'news ipp mar',
#  'iatl preliminari announc',
#  'consol last call paper',
#  'new www server univers edinburgh',
#  'dictionari subcategor frame',
#  'affric one segment two',
#  'job japanes',
#  'contrast grammar www home page',
#  'est',
#  'jeonju univers chonju korea',
#  'job linguistiqu informatiqu comput linguist',
#  '',
#  'linguist nameserv',
#  'nd call paper dgf meet',
#  'l theori job ad',
#  'sum histori capitalis english',
#  'call paper',
#  'avail',
#  'programm cssp',
#  'job open',
#  'la thematis dan le langu',
#  '',
#  'softwar experiment mt system',
#  'sum qs first name',
#  'lanuag wayana',
#  'see',
#  'telri rd european seminar announc',
#  'job soa',
#  'fwd cantones english bilingu research associ',
#  'program phonolog morpholog confer marburg',
#  'confidenti report',
#  'invit',
#  'wasteland darker side desir',
#  'free live video sex',
#  'sum multimod refer',
#  'queri',
#  'sum ref formal model discours',
#  'iee colloq london may ground represent sharkey mc',
#  'materi learn luganda',
#  'avail',
#  'avail',
#  'never forget',
#  'respons linguist list queri',
#  'sum discuss human non human languag',
#  'avail',
#  'keep',
#  'avail',
#  'student phonolog workshop ling inst',
#  'book review want',
#  'comput mediat convers',
#  'new list arcl',
#  'queri physic appear word',
#  'request written corpu variou genr',
#  'summari french cours',
#  'call paper',
#  'deserv break',
#  'freshest email address pro newbi',
#  'correspond friend',
#  'find n want know',
#  'est ce que question',
#  'referenc exampl number wp',
#  'formal semant sign ed languag',
#  'summari german ts tsch',
#  'conf lacl nanci franc sept',
#  'five word lot languag',
#  'avail',
#  'symposium spanish linguist linguist spain',
#  'q van lancker automat speech preprint',
#  'tei confer remind',
#  'appel euralex',
#  'avail',
#  'avail',
#  'even steal ident',
#  'avail',
#  'wccfl call paper',
#  'know need',
#  'hello',
#  'call review new url call site',
#  'whatev happen',
#  'second call paper option workshop utrecht',
#  'marked bibliographi',
#  'gurt long post',
#  'new discuss list',
#  'de proverbio news',
#  'shanghaihua speaker want',
#  'south slavic phonolog',
#  'gl schedul updat',
#  'conf melbourn univers postgradu confer',
#  'summari grasshopp mind',
#  'e h tuttl sumari',
#  'estuari english',
#  'th annual conf cognit scienc societi',
#  'line confer',
#  'celtic languag learn confer',
#  'cocosda rhode',
#  'japanes korean linguist',
#  'formal grammar',
#  'fresh chines dialect fieldwork confer last call',
#  'discontinu constitu',
#  'canadian english',
#  'syldavian tutori',
#  'avail',
#  'pass',
#  'free trial membership',
#  'obligatori affix summari',
#  'creat new credit file legal day',
#  'confer announc',
#  'new capit fm',
#  'summari elvi latin',
#  'grant aid avail',
#  'japanes confer',
#  'announc universit de genev',
#  'avail',
#  'call spanish us contact',
#  'workshop announc articulatori databas',
#  'site',
#  'check worth look',
#  'releas million',
#  'make day within month',
#  'avail',
#  'avail',
#  'etymo dict',
#  'linguistisch kolloquium kassel',
#  'spontan nasalis',
#  'special journal issu comput mediat discours analysi',
#  'digit record',
#  'fifth intern symposium',
#  'possess',
#  'free phonesex',
#  'need money',
#  'refinanc never easi',
#  '',
#  'icl seoul rd final announc program',
#  'tesol institut venezuela',
#  'autumn school gldv',
#  'sum function word',
#  '',
#  'confer call',
#  'comp ling summer school',
#  'june boolean confer',
#  'toc',
#  'ccall celao',
#  'would like',
#  'inform age',
#  'enjoy sex',
#  'return ask',
#  'sum sign sing',
#  'th univers wisconsin milwauke linguist symposium',
#  'old irish expert requir quick queri',
#  'review arbor window',
#  'prolamat first announc call paper',
#  'job',
#  'teach job french german korea',
#  'free trial membership',
#  'dirt cheap hard drive',
#  'investig anyon right browser',
#  'servic updat',
#  'spring phonolog job',
#  'sociolinguist dialect list',
#  'discours textbook',
#  'obituari jochem schindler',
#  'sum asl dictionari cd rom',
#  'sum refer',
#  'e h tuttl',
#  'journal japanes linguist vol',
#  'earn everi time phone ring',
#  'avail',
#  'releas million',
#  'free music audio book news softwar',
#  'posit avail',
#  'nlp job summari',
#  'refer romanian',
#  'sum verbal pronomin featur differ',
#  'queri intern congress linguist',
#  'sixth jk confer',
#  'turn measur',
#  'summari whatev happen',
#  'job opportun linguist intern posit',
#  'ad stop pain fast',
#  'afford famili dental care',
#  'return invest',
#  'new capit fm',
#  'job post',
#  'sum e h tuttl',
#  'build calb tv descrambl part',
#  'secret internet',
#  'creat wealth america',
#  'discov instant publish cd rom unlimit profit',
#  'posit announc',
#  'human comput posit ceth',
#  'avail',
#  'farsi persian light verb construct',
#  'nineteenth south asian languag analysi roundtabl',
#  'referenc exampl number wordperfect',
#  'sum lang www site',
#  'cgsw updat program',
#  'phd studentship',
#  'inoffici e text',
#  'call abstract listserv',
#  'avail',
#  'summer internship multimod system',
#  'job announc',
#  'sum speak tongu',
#  'th ichl manchest august',
#  'sum jakobson refer',
#  'elvi',
#  'summari c insert',
#  'thai lang school',
#  'sum singapor english',
#  'avail',
#  'optim workshop',
#  'avail',
#  'conf alt inaugur meet k mitxelena ihardunaldiak',
#  'esrc quota award master',
#  'bit charact',
#  'call paper iii nation linguist confer mexico',
#  'job research assist pragmat',
#  'hansa workshop ichl',
#  'ranlp call particip',
#  'latex pc',
#  'summari linguist scienc fiction',
#  'hwaet old english softwar',
#  'confer announc',
#  'isfc comput section',
#  'queri guid softwar linguist analysi',
#  'german text corpora noun taxonomi',
#  'sum uptalk',
#  'metathesi',
#  'next child languag research forum fwd',
#  'request inform soundex',
#  'refer formal descript discours',
#  'open close word class etc',
#  'semant ling theori program',
#  'english asian languag confer',
#  'seminar conserv endang languag',
#  'confer feb msu moscow',
#  'summari explet negat modern hebrew',
#  'ot programm tilburg confer',
#  'discours colloquium final program',
#  'item linguist',
#  'quichua info',
#  'id aa juliu ling ohio state edu tue',
#  'languag teach list',
#  'queri font',
#  'european linguist',
#  'font vietnames',
#  'foreign languag ad',
#  'labphon web page',
#  'avail',
#  'new book mitwpl syntax',
#  'function languag',
#  'special issu cl journal finit state method',
#  'multilingu workshop',
#  'new capit fm',
#  'tri call pleas call',
#  'comput semant',
#  'carni linguistlist org',
#  'th paclic',
#  'ppsn v call particip',
#  'new book sociolinguist',
#  'nd hispan lingusit symposium',
#  'new book syntax',
#  'import read care',
#  'alt iii',
#  'free sex',
#  'workshop comput intens method quantit linguist',
#  'llt v n',
#  'proceed gasla',
#  'tai studi',
#  'new book syntax',
#  'propos tutori workshop',
#  'program spanish contact',
#  'toc anthropolog linguist vol',
#  'new book languag plan',
#  'specif languag impair',
#  'eurogp',
#  'visit us tropic',
#  'promot busi onlin',
#  'new book mitwpl phonolog syntax interfac',
#  'syllabl structur gestur time',
#  'congress storag comput linguist',
#  'nd call tl',
#  'syntax syntax semant interfac',
#  'histor linguist',
#  'pidgin creol',
#  'electr motor',
#  'hil phonolog hilp',
#  'think',
#  'endang languag workshop',
#  'theoret descript linguist',
#  'new book clinic phonet',
#  'conf nd colloquium linguist kassel',
#  'spanish unit state confer',
#  'workshop visual represent interpret',
#  'workshop ellipsi conjunct',
#  'special issu cl journal finit state method nlp',
#  'snow',
#  'avail',
#  'new book hittit etymolog dictionari',
#  'refer',
#  'syntax philosophi lang',
#  'new book phonet phonolog',
#  'lacl logic aspect comput ling',
#  'new book mitwpl acquisit process',
#  'linguist theori',
#  'book function linguist',
#  'confer dgf cl',
#  'great line casino',
#  'request',
#  'new recent titl syntax morpholog',
#  'th intl conf asian african lang',
#  'th intl conf conceptu structur',
#  'epia call particip',
#  'cimca',
#  'toc ijglsa',
#  'book pragmat',
#  'lexic semant tag',
#  'new book mitwpl semant',
#  'holiday florida',
#  'book announc classic reissu',
#  'good luck',
#  'creat sens text realiti',
#  'workshop interlingua',
#  'new book english linguist',
#  'perceiv perform gender',
#  'new capitalfm',
#  'web page al',
#  'save money phone bill',
#  'time map phonolog',
#  'book ferdinand de saussur cur de lingvistica generala',
#  'conv div dialect read sept',
#  'glow',
#  'conf maritim terminolog',
#  'kbc nd call paper',
#  'semant syntax semant interfac',
#  'avail review phonolog',
#  'texa linguist societi',
#  'win porsch polit empow internet user',
#  'workshop embed mt system call paper',
#  'skytop sale save digit camera',
#  'ecdl final call particip',
#  'new book morpholog',
#  'extra holiday',
#  'sky yearbook linguist associ finland',
#  'new public web',
#  'avail review',
#  'lagb autumn meet',
#  'new book state modern american linguist',
#  'fast deliveri',
#  'move bill gate',
#  'new public australian languag',
#  'call genet program book propos',
#  'workshop embodi convers charact',
#  'languag confer',
#  'tl confer proced',
#  'new capit fm',
#  'nd intl symposium bilingu',
#  'new book multimedia languag cours',
#  'languag acquisit gala',
#  'semant syntax semant interfac languag acquisit',
#  'cute karen give free shock sex',
#  'rd intl conf mainten loss minor lang',
#  'new book languag process',
#  'new book histor linguist',
#  'incom tax electron file fast refund busi opportun',
#  'premium adult content',
#  'literatur philolog comput',
#  'phonolog phonet',
#  'converg diverg dialect conf final',
#  'contragram',
#  'nel program',
#  'mistress shave invit free fetish parti',
#  'mini workshop split constitu',
#  'th scandinavian confer linguist',
#  'nd acm intern confer digit librari',
#  'tanlp workshop final call paper',
#  'free live video sex',
#  'armenian ling',
#  'varieti english',
#  'harold orton centenari confer',
#  'best debt elimin softwar avail free demo great gift',
#  'cole acl last call particip',
#  'new book cognit linguist',
#  'new perspect languag acquisit revis',
#  'urgent buy alert',
#  'confer mental lexicon',
#  'contrast linguist translat',
#  'call workshop american indigen languag wail',
#  'syntax',
#  'programm workshop modal sle',
#  'secret hardcor sex site',
#  'secret hardcor sex site',
#  'hpsg program',
#  'sposs program',
#  'hypermedia den geisteswissenschaften',
#  'new book languag chang function linguist',
#  'perceiv perform gender',
#  'esslli workshop lexic semant context',
#  'de dag proceed workshop definit',
#  'iada confer',
#  'season greet santa',
#  'toward cultur situat agent',
#  'cole acl workshop multilingu inform manag report',
#  'new uci dissert linguist',
#  'eureka',
#  'nineteenth annual cognit scienc confer',
#  'news tv pc',
#  'confer italian german legal languag',
#  'consol',
#  'final call acl eacl workshop anaphora resolut',
#  'grammar bella coola',
#  'ld call particip',
#  'journal languag linguist vol januari june',
#  'call paper panel telephon call',
#  'new mitwpl book syntax semant',
#  'avail review semant pragmat syntax',
#  'psycholinguist neurolinguist',
#  'call neural symbol process',
#  'toc bg',
#  'syntax',
#  'languag metaphor metaphor languag session aaa',
#  'book nlp use prolog',
#  'new book van de vijver iambic issu',
#  'teflin',
#  'machin translat',
#  'glot intern',
#  'free credit',
#  'new book',
#  'workshop complex languag contact acquisit chang',
#  'comput intens method quantit ling',
#  'new recent titl gener linguist',
#  'new book human cognit process',
#  'stylist',
#  'german linguist annual confer',
#  'tree adjoin grammar workshop',
#  'get money stuf envelop',
#  'book pragmat',
#  'feminist confer call paper',
#  'tabl content glot intern',
#  'univers grammar ling anthropolog',
#  'special volum relev theori',
#  'error languag learn',
#  'call paper post communist languag chang',
#  'icei call paper',
#  'sociolinguist anthropolog linguist',
#  'urgent buy recommend',
#  'new book sociolinguist',
#  'last cfp acm sac track coordin',
#  'translat',
#  'new book use comput linguist',
#  'new book pragmat',
#  'book translat',
#  'avail review',
#  'hong kong journal appli linguist',
#  'european confer artifici intellig',
#  'avail review semant lexic databas case grammar',
#  'adult ad viva la revolut',
#  'book pidgin creol ocean ling',
#  'descript linguist',
#  'ila confer call paper',
#  'new book semant pragmat philosophi languag',
#  'book semant',
#  'context first call paper',
#  'new book german linguist',
#  'sociolinguist anthropolog linguist',
#  'new book atom bind',
#  'new book philosophi languag',
#  'vmc wsh prosodi mean',
#  'new mitwpl book argument structur aspect',
#  'negat syntax semant pragmat',
#  'major varieti english',
#  'philosophi lang',
#  'new book bolognesi phonolog campidanian sardinian',
#  'new book phonolog',
#  'finalist announc',
#  'mt summit cfp',
#  'univers degre program',
#  'bg',
#  'special offer eu workshop',
#  'german syntax workshop esslli',
#  'konven',
#  'call paper dgf meet',
#  'translat studi',
#  'muc call particip',
#  'amlap call abstract',
#  'new capitalfm com',
#  'hello',
#  'earli registr deadlin cimql',
#  'central japan languag educ ws',
#  'new book semant',
#  'new book languag acquisit',
#  'sociolinguist',
#  'journal translat textlinguist',
#  'ecai final call particip',
#  'meet atlant provinc linguist associ',
#  'new inform int congress terminolog basqu countri',
#  'new titl grammatic',
#  'summer school histori linguist',
#  'book phonet inton',
#  'call gener linguist',
#  'phonolog phonet workshop',
#  'semant',
#  'avail review syntax morpholog',
#  'english languag',
#  'conf ind arian indo iranian indo european',
#  'wolfram schill est american english',
#  'sinn und bedeutung rd call',
#  'conf translat comput',
#  'complex languag contact acquisit chang',
#  'scari',
#  'tabl rond sur la langu et la litteratur yiddish',
#  'new book syntax morpholog',
#  'book linguist theori',
#  'chamito semit confer',
#  'new book pragmat',
#  'baltic',
#  'esslli student session nd cfp',
#  'univers grammar',
#  'sociolinguist symposium updat',
#  'call glow phonolog workshop',
#  'brighter better faster ever',
#  'syntax',
#  'gener approach sla iv',
#  'new refer titl',
#  'journal cognit system research',
#  'avail',
#  'workshop languag space',
#  'erni',
#  'aspect bilingu ancient world',
#  'twlt twent workshop languag technolog',
#  'second call particip ecdl',
#  'journe de rochebrun',
#  'confer announc',
#  'third utrecht biannual phonolog workshop',
#  'psycholinguist',
#  'new book phonet speech product',
#  'call weisgerb colloquium',
#  'visit us tropic',
#  'request',
#  'conf salsa iii',
#  'avail',
#  'queri',
#  'urgent lehrstuhl fuer allgemein sprachwissenschaft vacanc',
#  'studi e mail linguist',
#  'judgment fatigu summari part',
#  'nativ speaker intuit',
#  'celtic linguist',
#  'rate loss basic vocabulari',
#  'qs metal',
#  'call paper acl corpu workshop',
#  'new www server germani',
#  'international arbeitstagung f r computereinsatz der',
#  'linguist phonet request inform',
#  'arab studi',
#  'langua et grammair modifi date',
#  'discours confer final call',
#  'queri pleas',
#  'compar syntax two languag one grammar',
#  'open letter languag',
#  'nel date last',
#  'q welsh internet',
#  'queri pseudo explan',
#  'sociolinguist reader',
#  'avail',
#  'call paper languag prehistori south asia',
#  'number invari summari',
#  'qs kinship term',
#  'hpsg slash',
#  'compar syntax',
#  'comput teach human',
#  'research studentship phonet',
#  'queri madam chairwoman',
#  'wccfl xiv last call paper',
#  'bisfai call paper second announc',
#  'vacat',
#  'n orbit cyberspac skyrocket',
#  'school la chines second languag',
#  'nativ speaker intuit',
#  'queri differ',
#  'req info indian corpora',
#  'cfp recent advanc nlp',
#  'call paper',
#  'queri',
#  'could',
#  'sum hold compuls exist',
#  'address john thayer jensen',
#  'sum word processor linguist',
#  'summari sri lanka',
#  'sum nativ speaker intuit',
#  'inform request',
#  'info wilhelm von timroth',
#  'know background',
#  'open letter languag',
#  'avail',
#  'dental optic plan',
#  'sum analog sg',
#  'queri write phonolog',
#  'labov tens',
#  'queri preserv field record',
#  'judgment fatigu summari part ii stromswold ross tang boyland',
#  'could',
#  'compar method',
#  'sum softwar',
#  'qs laryng phonet',
#  'languag legisl confer',
#  'sum formerli product morpholog process',
#  'lat amer indian lit symposium',
#  'syllabu undergradu socio linguist cours',
#  'nativ speaker intuit',
#  'univers',
#  'amaz health benefit green tea reveal',
#  'job post',
#  'avail',
#  'pleas read wont regret',
#  'appli linguist posit',
#  'sum vowel length orthographi',
#  'ijcai workshop context nlp',
#  'job comput lexicographi portugues italian dutch',
#  'peopl bilingu summari',
#  'job max planck institut psycholinguist',
#  'final call scil vii',
#  'avail',
#  'job open english socio appli',
#  'get rock tonight',
#  'job opportun',
#  'nativ speaker intuit',
#  'sum comput transcript',
#  'get rock tonight',
#  'sum walloon',
#  'go speedrac go go speedrac go',
#  'avail',
#  'sum',
#  'postdoctor fellowship cognit scienc avail',
#  'summ concept unknown dutch',
#  'uk linguist invit',
#  'job open',
#  'rain fall water summari',
#  'avail',
#  'job announc',
#  'distribut',
#  'futuresign',
#  'job posit',
#  'new softwar',
#  'hottest new busi opportun internet',
#  'avail',
#  'final voiceless velar fric stop',
#  'non linguist notic speech',
#  'call book propos',
#  'tag corpora summari',
#  'univers durham chair japanes',
#  'compar method',
#  'thank',
#  'usag base model symposium',
#  'avail',
#  'typolog histor chang',
#  'list languag list version',
#  'univers alabama tesol program',
#  '',
#  'rel pronoun famili pet cont',
#  'futuresign',
#  'sapir whorf',
#  'adv instant publish press releas',
#  'avail',
#  'open letter languag',
#  'compar method',
#  'cgsw program',
#  'font',
#  'sum clitic doubl spanish',
#  'linguist scienc',
#  'women studi northern illinoi univers',
#  'linguist associ great britain',
#  ...]

# %%
# creating a separate list for storing the processed messages of the column 'message'
message=[]
for i in range(0, len(df['message'])):
    review=df['message'][i].lower()
    review=review.split()
    review=[stemmer.stem(word) for word in review if not word in string.punctuation if not word in stopwords.words('english')]
    review= ' '.join(review)
    message.append(review)
    
message
# Out:
# ["content length 3386 apple-iss research center us 10 million joint ventur appl comput inc institut system scienc nation univers singapor locat singapor look senior speech scientist success candid research expertis comput linguist includ natur languag process english chines statist languag model knowledg state-of the-art corpus-bas n gram languag model cach languag model part-of speech languag model requir text speech project leader success candid research expertis expertis two follow area comput linguist includ natur languag pars lexic databas design statist languag model text token normal prosod analysi substanti knowledg phonolog syntax semant chines requir knowledg acoust phonet speech signal process desir candid phd least 2 4 year relev work experi technic msc degre least 5 7 year experienc e strong softwar engin skill includ design implement product requir posit knowledg c c unix prefer unix c programm look experienc unix c programm prefer good industri experi join us break new frontier strong knowledg unix tool compil linker make x window e mac experi matlab requir sun silicon graphic experi advantag programm less two year industri experi need appli posit includ interact scientist nation univers singapor appl 's speech research product effort locat cupertino california attend public intern scientif engin confer encourag benefit includ intern competit salari hous subsidi reloc expens send complet resum enclos person particular qualif experi contact telephon number mr jean luc lebrun center manag appl iss research center institut system scienc heng mui keng terrac singapor 0511 tel 65 772-6571 fax 65 776-4005 email jllebrun iss nu sg",
#  'lang classif grime joseph e barbara f grime ethnologu languag famili index pb isbn 0-88312 708 3 vi 116 pp 14 00 summer institut linguist companion volum ethnologu languag world twelfth edit list languag famili world sub-group shown tree arrang broadest classif languag famili languag famili index facilit locat languag name ethnologu make data access internet academ book sil org languag refer lang cultur gregerson marilyn ritual belief kinship sulawesi pb isbn 0-88312 621 4 ix 194 pp 25 00 summer institut linguist seven artic
internet home page activ follow address http clwww essex ac uk lagb electron network pleas join lagb electron network use dissemin lagb inform consult member quickli subscrib send messag add lagb listserv postman essex ac uk programm monday 18 septemb 1995 2 00 workshop ellipsi focu anaphora organis david adger york particip edwin william princeton carolin heycock edinburgh ruth kempson soa wynn chao soa 7 45 henri sweet lectur 1995 edwin william princeton tuesday 19 septemb 1995 session 9 00 j de wind amsterdam invert subject french nomin case check explet pro antisymmetr minim 9 40 anna pettiward soa agreement option french conflict account 10 20 alison henri univers ulster jordanstown dialect variat minimalist syntax session b 9 00 richard breheni ucl revis relev theori enrich 9 40 vladimir zegarac middlesex three connect serbo croat 10 20 anna papafrag ucl comprehens metonymi session c 9 00 andrew spencer essex agreement morpholog morpholog 9 40 lynn j cahil gerald gazdar sussex syllabl inflect german 10 20 andrew hippisley surrey russian lexem format lexeme-bas approach deriv morpholog datr session 11 30 helg lodrup oslo norwegian result unaccus lexic map theori 12 10 corinn cort barcelona unaccus hypothesi syntax lexic semant interfac session b 11 30 marjolein groefsema hertfordshir process relev 12 10 mark durrant peatfield william marslen wilson role discours represent immedi zero anaphor resolut session c 11 30 victoria c mueller gathercol bangor florida acquisit mass count distinct bilingu vs monolingu children 12 10 grevil g corbett mariann mithun surrey univers california santa barbara associ form central alaskan yup ik implic typolog number system session 2 00 richard hudson ucl syntact complex 2 40 josef taglicht hebrew univers jerusalem syntact constraint inton phrase english 3 20 dimitra kolliak edinburgh possess pseudo possess hpsg account session b 2 00 hussein al age essex optim degener super heavi syllabl msa 2 40 zaharani ahmad essex optim malay vowel sequenc 3 20 kuniya nasukawa tohoku gakuin melod structur constraint-rank japanes verbal inflexion session c 2 00 maggi tallerman durham middl welsh histor infinit 2 40 najib jarad bangor aleppo rise middl english infinit 3 20 siobh n cottel bangor predic copular cleft construct modern irish 4 30 lagb busi meet 5 30 special guest lectur greg stump kentucki autonomi morphom index 7 45 languag tutori kayardild nichola evan melbourn wednesday 20 septemb 1995 session 9 00 peter sell stanford subjec ...
#  ...]

# %% [markdown]
# #### Using Message (actual message) as input
# #### Using Tfidvectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

vec=TfidfVectorizer()
x=vec.fit_transform(message).toarray()

# %%
y=df['label']

# %%
train_x,test_x,train_y,test_y=train_test_split(x,y,random_state=42,test_size=0.20)

# %%
from sklearn.naive_bayes import GaussianNB
gb=GaussianNB()
gb.fit(train_x,train_y)
pred=gb.predict(test_x)
print("The accuracy score is", accuracy_score(test_y,pred))
# Out:
# The accuracy score is 0.9222797927461139

# %%
print(confusion_matrix(test_y,pred))
print(classification_report(test_y,pred))
# Out:
# [[461   3]
#  [ 42  73]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95       464
#            1       0.96      0.63      0.76       115
#
#     accuracy                           0.92       579
#    macro avg       0.94      0.81      0.86       579
# weighted avg       0.93      0.92      0.92       579

# %% [markdown]
# #### using countvectorizer

# %%
count=CountVectorizer()
x=count.fit_transform(message).toarray()

# %%
train_x,test_x,train_y,test_y=train_test_split(x,y,random_state=42,test_size=0.20)

# %%
from sklearn.naive_bayes import GaussianNB
gb=GaussianNB()
gb.fit(train_x,train_y)
pred=gb.predict(test_x)
print("The accuracy score is", accuracy_score(test_y,pred))
# Out:
# The accuracy score is 0.927461139896373

# %%
print(confusion_matrix(test_y,pred))
print(classification_report(test_y,pred))
# Out:
# [[461   3]
#  [ 39  76]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96       464
#            1       0.96      0.66      0.78       115
#
#     accuracy                           0.93       579
#    macro avg       0.94      0.83      0.87       579
# weighted avg       0.93      0.93      0.92       579

# %% [markdown]
# #### trying other classifiers using countvectorizer
# since count vectorizer is giving better results we can consider the same

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
AS=[]
CV=[]

models=[LogisticRegression(),DecisionTreeClassifier(),KNeighborsClassifier(),SVC(),GaussianNB()]

for i in models:
    i.fit(train_x,train_y)
    pred=i.predict(test_x)
    print(i)
    acc_score=accuracy_score(pred,test_y)
    print("\nAccuracy Score",acc_score)
    AS.append(acc_score)
    print(classification_report(pred,test_y))
    print(confusion_matrix)
    print("")
    cvs=cross_val_score(i,x,y,cv=5).mean()
    print("The cross validation score is", cvs)
    CV.append(cvs)
    print("")
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)
#
# Accuracy Score 0.998272884283247
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       465
#            1       0.99      1.00      1.00       114
#
#     accuracy                           1.00       579
#    macro avg       1.00      1.00      1.00       579
# weighted avg       1.00      1.00      1.00       579
#
# <function confusion_matrix at 0x0000024015BDDA68>
#
# The cross validation score is 0.9920486856630848
#
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')
#
# Accuracy Score 0.9671848013816926
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       469
#            1       0.90      0.94      0.92       110
#
#     accuracy                           0.97       579
#    macro avg       0.94      0.96      0.95       579
# weighted avg       0.97      0.97      0.97       579
#
# <function confusion_matrix at 0x0000024015BDDA68>
#
# The cross validation score is 0.9550740026117962
#
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')
#
# Accuracy Score 0.9430051813471503
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       455
#            1       0.90      0.83      0.86       124
#
#     accuracy                           0.94       579
#    macro avg       0.93      0.90      0.91       579
# weighted avg       0.94      0.94      0.94       579
#
# <function confusion_matrix at 0x0000024015BDDA68>
#
# The cross validation score is 0.9135819526814395
#
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)
#
# Accuracy Score 0.853195164075993
#               precision    recall  f1-score   support
#
#            0       1.00      0.85      0.92       549
#            1       0.26      1.00      0.41        30
#
#     accuracy                           0.85       579
#    macro avg       0.63      0.92      0.66       579
# weighted avg       0.96      0.85      0.89       579
#
# <function confusion_matrix at 0x0000024015BDDA68>
#
# The cross validation score is 0.8721006722377019
#
# GaussianNB(priors=None, var_smoothing=1e-09)
#
# Accuracy Score 0.927461139896373
#               precision    recall  f1-score   support
#
#            0       0.99      0.92      0.96       500
#            1       0.66      0.96      0.78        79
#
#     accuracy                           0.93       579
#    macro avg       0.83      0.94      0.87       579
# weighted avg       0.95      0.93      0.93       579
#
# <function confusion_matrix at 0x0000024015BDDA68>
#
# The cross validation score is 0.9391671947342033

# %%
score=pd.DataFrame({'Models':models,'Accuracy Score':AS,'Cross Validation Score':CV})
score
# Out:
#                                               Models  Accuracy Score  \
# 0  LogisticRegression(C=1.0, class_weight=None, d...        0.998273
# 1  DecisionTreeClassifier(class_weight=None, crit...        0.967185
# 2  KNeighborsClassifier(algorithm='auto', leaf_si...        0.943005
# 3  SVC(C=1.0, cache_size=200, class_weight=None, ...        0.853195
# 4       GaussianNB(priors=None, var_smoothing=1e-09)        0.927461
#
#    Cross Validation Score
# 0                0.992049
# 1                0.955074
# 2                0.913582
# 3                0.872101
# 4                0.939167

# %% [markdown]
# Conclusion:
# Logistic Regression is giving best accuracy score and cross validation score. So we can conclude the same.

# %%
#Saving the logistic regression model
lg=LogisticRegression()
lg.fit(train_x,train_y)
pred=lg.predict(test_x)
acc_score=accuracy_score(pred,test_y)
print("\nAccuracy Score",acc_score)
cvs=cross_val_score(lg,x,y,cv=5).mean()
print("The cross validation score is", cvs)

    
from sklearn.externals import joblib
joblib.dump(lg,"Spam_Mails_LG.pkl")
# Out:
# Accuracy Score 0.998272884283247
# The cross validation score is 0.9920486856630848
# D:\anaconda\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# ['Spam_Mails_LG.pkl']

# %% [markdown]
# ##### Message subject as input instead of message

# %%
# we can try and see if we can keep subject as the input
x1=vec.fit_transform(subject).toarray()

# %%
train_x,test_x,train_y,test_y=train_test_split(x1,y,random_state=42,test_size=0.20)

# %%
# trying different models
models=[LogisticRegression(),DecisionTreeClassifier(),KNeighborsClassifier(),SVC(),GaussianNB()]
AS=[]
CV=[]


for i in models:
    i.fit(train_x,train_y)
    pred=i.predict(test_x)
    print(i)
    acc_score=accuracy_score(pred,test_y)
    print("\nAccuracy Score",acc_score)
    AS.append(acc_score)
    print(classification_report(pred,test_y))
    print(confusion_matrix)
    print("")
    cvs=cross_val_score(i,x,y,cv=5).mean()
    print("The cross validation score is", cvs)
    CV.append(cvs)
    print("")
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)
#
# Accuracy Score 0.853195164075993
#               precision    recall  f1-score   support
#
#            0       1.00      0.85      0.92       549
#            1       0.26      1.00      0.41        30
#
#     accuracy                           0.85       579
#    macro avg       0.63      0.92      0.66       579
# weighted avg       0.96      0.85      0.89       579
#
# <function confusion_matrix at 0x0000024015BDDA68>
#
# The cross validation score is 0.9920486856630848
#
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')
#
# Accuracy Score 0.8911917098445595
#               precision    recall  f1-score   support
#
#            0       0.98      0.89      0.94       509
#            1       0.53      0.87      0.66        70
#
#     accuracy                           0.89       579
#    macro avg       0.76      0.88      0.80       579
# weighted avg       0.93      0.89      0.90       579
#
# <function confusion_matrix at 0x0000024015BDDA68>
#
# The cross validation score is 0.9561037064880077
#
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')
#
# Accuracy Score 0.7841105354058722
#               precision    recall  f1-score   support
#
#            0       0.86      0.87      0.86       457
#            1       0.49      0.46      0.47       122
#
#     accuracy                           0.78       579
#    macro avg       0.67      0.66      0.67       579
# weighted avg       0.78      0.78      0.78       579
#
# <function confusion_matrix at 0x0000024015BDDA68>
#
# The cross validation score is 0.9135819526814395
#
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)
#
# Accuracy Score 0.8013816925734024
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89       579
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.80       579
#    macro avg       0.50      0.40      0.44       579
# weighted avg       1.00      0.80      0.89       579
#
# <function confusion_matrix at 0x0000024015BDDA68>
#
# The cross validation score is 0.8721006722377019
#
# GaussianNB(priors=None, var_smoothing=1e-09)
#
# Accuracy Score 0.8911917098445595
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93       433
#            1       0.86      0.68      0.76       146
#
#     accuracy                           0.89       579
#    macro avg       0.88      0.82      0.84       579
# weighted avg       0.89      0.89      0.89       579
#
# <function confusion_matrix at 0x0000024015BDDA68>
#
# The cross validation score is 0.9391671947342033

# %%
score=pd.DataFrame({'Models':models,'Accuracy Score':AS,'Cross Validation Score':CV})
score
# Out:
#                                               Models  Accuracy Score  \
# 0  LogisticRegression(C=1.0, class_weight=None, d...        0.853195
# 1  DecisionTreeClassifier(class_weight=None, crit...        0.891192
# 2  KNeighborsClassifier(algorithm='auto', leaf_si...        0.784111
# 3  SVC(C=1.0, cache_size=200, class_weight=None, ...        0.801382
# 4       GaussianNB(priors=None, var_smoothing=1e-09)        0.891192
#
#    Cross Validation Score
# 0                0.992049
# 1                0.956104
# 2                0.913582
# 3                0.872101
# 4                0.939167

# %%
# Lets use gridsearchcv on decisiontree to get better results
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
parameters={'criterion':('gini','entropy'), 'splitter':('best','random')}
gddt=GridSearchCV(dt,parameters)
gddt.fit(train_x,train_y)
gddt.best_params_
# Out:
# {'criterion': 'entropy', 'splitter': 'random'}

# %%
# Let us finalise the Decision Tree classifier which is giving better Accuracy and Cross validation score
dt=DecisionTreeClassifier(criterion='entropy',splitter='random')
dt.fit(train_x,train_y)
pred=dt.predict(test_x)
print("Accuracy score is", accuracy_score(test_y,pred))
print("The Cross Validation Score is", cross_val_score(dt,x,y,cv=5).mean())
# Out:
# Accuracy score is 0.8981001727115717
# The Cross Validation Score is 0.9550674411794586

# %%
# Saving the model
joblib.dump(dt,"Spam_mail_on_subject.pkl")
# Out:
# ['Spam_mail_on_subject.pkl']
